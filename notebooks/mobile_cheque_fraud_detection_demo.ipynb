# %% [markdown]
# # Mobile Cheque Fraud Detection Demo\nThis notebook demonstrates sample feature loading, model training, and scoring.

# %%
import pandas as pd\ndf = pd.read_csv('../data/sample/sample_cheque_features.csv')\ndf.head()
